# %% [markdown]
# <a href="https://colab.research.google.com/github/shihapalden/Prodigy-InfoTech-ML-01-02/blob/main/Retail_Customer_Grouping_Based_on_Purchase_Behavior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Load the dataset
df = pd.read_csv("retail_customers.csv")

# %%
# Drop the customer_id column
X = df[["age", "annual_income", "spending_score"]]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Fit KMeans with 3 clusters (you can use the elbow method to choose the best K)
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(X_scaled)

# Display cluster centers
print("Cluster centers:\n", kmeans.cluster_centers_)
# Out:
# Cluster centers:
#  [[-0.72112338 -0.40943632  1.03695382]
#  [ 0.83509542  0.81060119 -0.48794355]
#  [-0.61699878 -1.10733913 -0.71679619]]

# %%
# Plotting clusters
plt.figure(figsize=(8, 6))
plt.scatter(df["annual_income"], df["spending_score"], c=df["cluster"], cmap="viridis")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Customer Segmentation (K-Means Clustering)")
plt.grid(True)
plt.show()
